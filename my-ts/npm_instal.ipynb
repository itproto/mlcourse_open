# %%
# !npm i d3 lodash node-fetch 
# !npm install stats-analysis
# !ls
# Out:
# | |---------------------------------------------------------------------------|
# / |---------------------------------------------------------------------------|
# - |---------------------------------------------------------------------------|
# - |---------------------------------------------------------------------------|
# | |---------------------------------------------------------------------------|
# - |---------------------------------------------------------------------------|
# | |---------------------------------------------------------------------------|
# / |---------------------------------------------------------------------------|
# | |---------------------------------------------------------------------------|
# loadRequestedDeps -> afte | |##########---------------------------------------|
# loadRequestedDeps -> afte \ |##########---------------------------------------|
# loadRequestedDeps         \ |##########---------------------------------------|
# ...
