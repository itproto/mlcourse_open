# %%
from __future__ import division, print_function
# отключим всякие предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
import pylab as plt
# %matplotlib inline
import seaborn as sns
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (10, 8)

# %%
df = pd.read_csv('../../data/telecom_churn.csv');
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %% [markdown]
# # Individual

# %%
df['Total day minutes'].hist()

# %%
sns.boxplot(df['Total day minutes'])

# %%
a = df.hist(figsize=(15,12));

# %% [markdown]
# # 2 Categorical

# %%
df['State'].value_counts().head()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# Name: State, dtype: int64

# %%
df['Churn'].value_counts().head()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts().plot(kind='bar', label='Churn');
plt.legend();
plt.title('Churn diturb');

# %%
sns.countplot(df['State'].head())
idxs = df['State'].value_counts().head().index;
sns.countplot( df[df['State'].isin(idxs)]['State'])

# %%
cor_mat = df.drop(['State', 'International plan', 'Voice mail plan',
                      'Area code'], axis=1).corr()
sns.heatmap(cor_mat);
